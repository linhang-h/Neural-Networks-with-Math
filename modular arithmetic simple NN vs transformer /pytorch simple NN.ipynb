# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %% [markdown]
# ## data prep

# %%
# --- Parameters ---
modulus = 17   # N in mod N
m = 3          # multiplier
b = 5          # bias term
n_samples = 1000  # number of training examples

# --- Generate the data ---
# x will be integers 0,1,...,n_samples-1.
x = np.arange(n_samples)
# f(x) = (m*x + b) mod modulus
y = (m * x + b) % modulus

# Convert to torch tensors.
# For the network we use float inputs and integer targets (for cross-entropy).
x_train = torch.tensor(x, dtype=torch.float32).unsqueeze(1)  # shape: [n_samples, 1]
y_train = torch.tensor(y, dtype=torch.long)                  # shape: [n_samples]

# %% [markdown]
# ## simple neural network

# %%
# --- Define a Simple MLP ---
class SimpleMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(SimpleMLP, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Linear(hidden_dim * 2, output_dim)
        )
    
    def forward(self, x):
        return self.net(x)

model = SimpleMLP(input_dim=1, hidden_dim=32, output_dim=modulus)


# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## training

# %%
# --- Training ---
batch_size = 32
dataset = torch.utils.data.TensorDataset(x_train, y_train)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

epochs = 100
for epoch in range(epochs):
    total_loss = 0.0
    correct = 0
    total = 0
    for batch_x, batch_y in dataloader:
        optimizer.zero_grad()
        outputs = model(batch_x)  # shape: [batch_size, modulus]
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item() * batch_x.size(0)
        # Calculate accuracy.
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch_y).sum().item()
        total += batch_y.size(0)
    
    avg_loss = total_loss / total
    accuracy = correct / total * 100
    print(f"Epoch {epoch+1}/{epochs} - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/100 - Loss: 29.7803, Accuracy: 4.70%
# Epoch 2/100 - Loss: 5.7300, Accuracy: 5.50%
# Epoch 3/100 - Loss: 3.9145, Accuracy: 6.20%
# Epoch 4/100 - Loss: 3.9736, Accuracy: 5.60%
# Epoch 5/100 - Loss: 3.9319, Accuracy: 5.70%
# Epoch 6/100 - Loss: 3.8523, Accuracy: 6.50%
# Epoch 7/100 - Loss: 3.8167, Accuracy: 4.80%
# Epoch 8/100 - Loss: 3.7159, Accuracy: 5.70%
# Epoch 9/100 - Loss: 4.0533, Accuracy: 5.00%
# Epoch 10/100 - Loss: 3.8890, Accuracy: 5.90%
# Epoch 11/100 - Loss: 4.2001, Accuracy: 7.40%
# Epoch 12/100 - Loss: 3.7188, Accuracy: 5.40%
# Epoch 13/100 - Loss: 3.5704, Accuracy: 4.70%
# Epoch 14/100 - Loss: 3.6755, Accuracy: 6.30%
# Epoch 15/100 - Loss: 4.4453, Accuracy: 5.60%
# Epoch 16/100 - Loss: 3.6926, Accuracy: 5.30%
# Epoch 17/100 - Loss: 3.9549, Accuracy: 6.10%
# Epoch 18/100 - Loss: 3.7168, Accuracy: 5.70%
# Epoch 19/100 - Loss: 4.2424, Accuracy: 5.30%
# Epoch 20/100 - Loss: 3.9151, Accuracy: 4.50%
# Epoch 21/100 - Loss: 3.7075, Accuracy: 5.90%
# Epoch 22/100 - Loss: 3.9583, Accuracy: 6.80%
# Epoch 23/100 - Loss: 4.1210, Accuracy: 6.40%
# Epoch 24/100 - Loss: 3.8325, Accuracy: 3.90%
# Epoch 25/100 - Loss: 3.7302, Accuracy: 7.10%
# Epoch 26/100 - Loss: 3.7914, Accuracy: 7.20%
# Epoch 27/100 - Loss: 4.0061, Accuracy: 5.90%
# Epoch 28/100 - Loss: 3.9136, Accuracy: 5.80%
# Epoch 29/100 - Loss: 3.7665, Accuracy: 5.50%
# Epoch 30/100 - Loss: 3.8114, Accuracy: 4.70%
# Epoch 31/100 - Loss: 3.7541, Accuracy: 5.30%
# Epoch 32/100 - Loss: 3.8843, Accuracy: 5.60%
# Epoch 33/100 - Loss: 3.6175, Accuracy: 5.40%
# Epoch 34/100 - Loss: 3.6213, Accuracy: 5.70%
# Epoch 35/100 - Loss: 3.8844, Accuracy: 5.30%
# Epoch 36/100 - Loss: 3.7124, Accuracy: 5.50%
# Epoch 37/100 - Loss: 3.7933, Accuracy: 4.90%
# Epoch 38/100 - Loss: 3.4816, Accuracy: 5.80%
# Epoch 39/100 - Loss: 3.8289, Accuracy: 6.60%
# Epoch 40/100 - Loss: 3.7618, Accuracy: 5.70%
# Epoch 41/100 - Loss: 3.4397, Accuracy: 6.60%
# Epoch 42/100 - Loss: 3.4363, Accuracy: 5.00%
# Epoch 43/100 - Loss: 3.4634, Accuracy: 6.30%
# Epoch 44/100 - Loss: 3.7358, Accuracy: 4.70%
# Epoch 45/100 - Loss: 4.1536, Accuracy: 4.40%
# Epoch 46/100 - Loss: 3.4235, Accuracy: 6.20%
# Epoch 47/100 - Loss: 3.7346, Accuracy: 6.30%
# Epoch 48/100 - Loss: 3.7252, Accuracy: 5.70%
# Epoch 49/100 - Loss: 3.2583, Accuracy: 6.60%
# Epoch 50/100 - Loss: 3.4139, Accuracy: 5.30%
# Epoch 51/100 - Loss: 3.5856, Accuracy: 5.60%
# Epoch 52/100 - Loss: 3.6243, Accuracy: 6.50%
# Epoch 53/100 - Loss: 3.2768, Accuracy: 4.50%
# Epoch 54/100 - Loss: 3.3835, Accuracy: 6.00%
# Epoch 55/100 - Loss: 3.5857, Accuracy: 6.10%
# Epoch 56/100 - Loss: 3.4159, Accuracy: 6.40%
# Epoch 57/100 - Loss: 3.3688, Accuracy: 6.00%
# Epoch 58/100 - Loss: 3.3597, Accuracy: 5.40%
# Epoch 59/100 - Loss: 3.4081, Accuracy: 6.70%
# Epoch 60/100 - Loss: 3.5983, Accuracy: 6.10%
# Epoch 61/100 - Loss: 3.5224, Accuracy: 5.40%
# Epoch 62/100 - Loss: 3.3967, Accuracy: 6.20%
# Epoch 63/100 - Loss: 3.4990, Accuracy: 5.50%
# Epoch 64/100 - Loss: 3.4489, Accuracy: 5.70%
# Epoch 65/100 - Loss: 3.4429, Accuracy: 5.90%
# Epoch 66/100 - Loss: 3.3503, Accuracy: 7.40%
# Epoch 67/100 - Loss: 3.3212, Accuracy: 7.10%
# Epoch 68/100 - Loss: 3.4308, Accuracy: 6.30%
# Epoch 69/100 - Loss: 3.2289, Accuracy: 6.90%
# Epoch 70/100 - Loss: 3.3657, Accuracy: 6.50%
# Epoch 71/100 - Loss: 3.4955, Accuracy: 5.10%
# Epoch 72/100 - Loss: 3.3537, Accuracy: 5.60%
# Epoch 73/100 - Loss: 3.6747, Accuracy: 6.20%
# Epoch 74/100 - Loss: 3.4247, Accuracy: 5.50%
# Epoch 75/100 - Loss: 3.4711, Accuracy: 6.00%
# Epoch 76/100 - Loss: 3.3647, Accuracy: 5.70%
# Epoch 77/100 - Loss: 3.6606, Accuracy: 5.60%
# Epoch 78/100 - Loss: 3.2294, Accuracy: 7.10%
# Epoch 79/100 - Loss: 3.2240, Accuracy: 6.10%
# Epoch 80/100 - Loss: 3.3221, Accuracy: 7.20%
# Epoch 81/100 - Loss: 3.2427, Accuracy: 6.20%
# Epoch 82/100 - Loss: 3.2847, Accuracy: 4.30%
# Epoch 83/100 - Loss: 3.2933, Accuracy: 5.40%
# Epoch 84/100 - Loss: 3.1976, Accuracy: 5.90%
# Epoch 85/100 - Loss: 3.2930, Accuracy: 5.90%
# Epoch 86/100 - Loss: 3.3350, Accuracy: 5.10%
# Epoch 87/100 - Loss: 3.3206, Accuracy: 5.20%
# Epoch 88/100 - Loss: 3.4244, Accuracy: 6.60%
# Epoch 89/100 - Loss: 3.2769, Accuracy: 5.30%
# Epoch 90/100 - Loss: 3.3613, Accuracy: 6.20%
# Epoch 91/100 - Loss: 3.2953, Accuracy: 7.50%
# Epoch 92/100 - Loss: 3.0656, Accuracy: 4.90%
# Epoch 93/100 - Loss: 3.2028, Accuracy: 6.90%
# Epoch 94/100 - Loss: 3.4495, Accuracy: 5.50%
# Epoch 95/100 - Loss: 3.3369, Accuracy: 5.70%
# Epoch 96/100 - Loss: 3.4285, Accuracy: 8.10%
# Epoch 97/100 - Loss: 3.3376, Accuracy: 4.50%
# Epoch 98/100 - Loss: 3.2725, Accuracy: 5.20%
# Epoch 99/100 - Loss: 3.1469, Accuracy: 5.90%
# Epoch 100/100 - Loss: 3.1815, Accuracy: 6.30%
